# %%
from Classifier import knn as knn
from Training import Datacreate as dc
import numpy as np
import matplotlib.pyplot as plt

# %%
LeftEye_path = "./Recordings/Fall_2020/OpenBCISession_2020-10-11_16-33-50-YAN-LEFT-EYE/OpenBCI-RAW-2020-10-11_16-38-59.txt"
LeftEye_label_path = "./Recordings/Labels/yanLeftEye"
RightEye_observations = dc.getObservationSet(LeftEye_path, LeftEye_label_path, 1000, [0,1,2], 'L_EYE')
# Out:
# /home/spasq/workspace/neuro/rcario/Training/Datacreate.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_groups = np.array(np.split(x, split_inds))
# /home/spasq/workspace/neuro/rcario/Training/Datacreate.py:88: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y_groups = np.array(np.split(y, split_inds))
# ...

# %%
channel0 = RightEye_observations[0]
x_groups0, y_groups0, t_groups0 = channel0[0]

channel1 = RightEye_observations[1]
x_groups1, y_groups1, t_groups1 = channel1[0]

channel2 = RightEye_observations[2]
x_groups2, y_groups2, t_groups2 = channel2[0]

l_groups = channel0[1]

l_groups[29]
# Out:
# array([1., 0., 0., 0., 0.])

# %%
for i,group in enumerate(l_groups):
    if group[0]!=1:
        print(i)
# Out:
# 32
# 43
# 54
# 63
# 74
# 85
# 97
# 107
# 118
# 128
# 139
# 148
# 160
# 172
# 182
# 192
# 202
# 212
# 225

# %%
plt.plot(x_groups0[32], y_groups0[32])
plt.plot(x_groups1[32], y_groups1[32])
plt.plot(x_groups2[32], y_groups2[32])

# %%
plt.plot(x_groups0[33], y_groups0[33])
plt.plot(x_groups1[33], y_groups1[33])
plt.plot(x_groups2[33], y_groups2[33])
